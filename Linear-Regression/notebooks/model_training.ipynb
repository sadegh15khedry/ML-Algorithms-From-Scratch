# %%
import sys
import os
# %matplotlib inline

sys.path.append(os.path.abspath('../src'))
from model_training import train_model
from utils import save_model, load_data, get_error

# %%
#loading the datasets
x_train = load_data("../datasets/ready/train/x_train.csv")
y_train = load_data("../datasets/ready/train/y_train.csv")

x_test = load_data("../datasets/ready/test/x_test.csv")
y_test = load_data("../datasets/ready/test/y_test.csv")

# %%
model_type = 'custom'
number_of_iterations = 1000
learning_rate = 0.0000001

# %%
#traingin the random forest model 
model = train_model(x_train, y_train, number_of_iterations, learning_rate, model_type)
# Out:
# 1000
# Iteration 0
# First few weights: [[4.40833159e-06 3.53611905e-05 2.09779410e-05 1.73460317e-07
#   1.19476004e-06]]
# Bias: 2.248095238095238e-06
# Iteration 100
# First few weights: [[-1.44524505e-04  2.00772164e-03  4.29750478e-04  8.36536265e-06
#    3.84059307e-05]]
# Bias: 8.093537323933282e-05
# Iteration 200
# First few weights: [[-4.82484320e-04  3.23967942e-03  1.82903023e-04  1.25521231e-05
#    4.19396490e-05]]
# Bias: 9.82985793482818e-05
# Iteration 300
# First few weights: [[-7.76572127e-04  4.33847388e-03 -5.71252021e-05  1.63058440e-05
#    4.39879332e-05]]
# Bias: 0.00011145586287856788
# Iteration 400
# First few weights: [[-1.02705132e-03  5.34952737e-03 -2.68704061e-04  1.98321104e-05
#    4.59432950e-05]]
# Bias: 0.0001231728338530178
# Iteration 500
# First few weights: [[-1.24217608e-03  6.29029209e-03 -4.56398120e-04  2.31814798e-05
#    4.78724339e-05]]
# Bias: 0.0001338170714264072
# Iteration 600
# First few weights: [[-1.42891319e-03  7.17395609e-03 -6.24811558e-04  2.63895855e-05
#    4.97836869e-05]]
# Bias: 0.0001436038550685934
# Iteration 700
# First few weights: [[-1.59286593e-03  8.01106817e-03 -7.77678710e-04  2.94847940e-05
#    5.16817882e-05]]
# Bias: 0.0001527024474298024
# Iteration 800
# First few weights: [[-1.73852955e-03  8.81009362e-03 -9.17997403e-04  3.24898456e-05
#    5.35704398e-05]]
# Bias: 0.00016124847309504817
# Iteration 900
# First few weights: [[-1.86950998e-03  9.57782789e-03 -1.04817301e-03  3.54229757e-05
#    5.54525957e-05]]
# Bias: 0.00016935071506366876

# %%
# Get predictions on the training data
y_pred_train = model.predict(x_train)

print (y_pred_train)
# Calculate Mean Squared Error (MSE)
mse_train =  get_error(y_train, y_pred_train)
print(f"Training MSE: {mse_train}")
# Out:
# [[24.84090758]
#  [23.72064128]
#  [15.5058173 ]
#  [22.67064084]
#  [23.74870461]
#  [23.87308152]
#  [22.98911233]
#  [23.9876846 ]
#  [24.07648956]
#  [23.71336362]
#  [23.75295335]
#  [23.69141563]
#  [23.08722232]
#  [-0.7594995 ]
#  [23.98614457]
#  [16.34810673]
#  [23.8396088 ]
#  [24.06758199]
#  [23.51505488]
#  [23.61003028]
#  [24.36617226]
#  [22.95872717]
#  [20.42010884]
#  [18.17234725]
#  [17.4488513 ]
#  [23.37712043]
#  [21.87642516]
#  [23.96555204]
#  [23.69276738]
#  [24.03987599]
#  [23.78156045]
#  [22.47804872]
#  [23.29371611]
#  [23.89421811]
#  [23.60814925]
#  [23.97153927]
#  [22.94765377]
#  [24.20395312]
#  [23.24684762]
#  [15.51292647]
#  [22.95374208]
#  [23.154816  ]
#  [20.89055984]
#  [22.07303463]
#  [23.8253777 ]
#  [23.24244848]
#  [24.13768263]
#  [ 0.1302828 ]
#  [14.17065804]
#  [22.06644472]
#  [23.49601889]
#  [22.8796962 ]
#  [24.79280345]
#  [21.02777294]
#  [19.20524938]
#  [22.81001142]
#  [23.94118208]
#  [24.47856146]
#  [24.50696036]
#  [23.86764495]
#  [24.3958942 ]
#  [23.71501727]
#  [23.50778385]
#  [24.09064935]
#  [23.983775  ]
#  [24.80788521]
#  [24.03705178]
#  [23.95130972]
#  [23.29864585]
#  [22.72301338]
#  [22.13609141]
#  [21.68171816]
#  [24.21738917]
#  [22.76687848]
#  [21.7576281 ]
#  [23.87324995]
#  [23.04008924]
#  [23.76010345]
#  [23.65911162]
#  [24.13982138]
#  [23.81347409]
#  [ 5.01682459]
#  [23.97525474]
#  [17.54795028]
#  [23.21040105]
#  [10.01797281]
#  [23.92324886]
#  [23.99805551]
#  [22.79239103]
#  [23.96171956]
#  [23.76323045]
#  [23.17939046]
#  [22.72522334]
#  [24.12505571]
#  [24.1745616 ]
#  [23.89966351]
#  [21.83029144]
#  [24.15957453]
#  [24.53030555]
#  [23.01204931]
#  [24.02745091]
#  [23.19678869]
#  [22.99652209]
#  [24.1533363 ]
#  [23.90409903]
#  [18.517105  ]
#  [23.97193875]
#  [23.95122165]
#  [20.25383095]
#  [21.62959355]
#  [23.6383638 ]
#  [23.07324966]
#  [18.25933973]
#  [23.1100789 ]
#  [-1.0038324 ]
#  [23.79211312]
#  [23.22356689]
#  [ 4.15980263]
#  [22.90642088]
#  [23.7281558 ]
#  [21.70964828]
#  [19.7013129 ]
#  [22.71581395]
#  [22.59659453]
#  [17.67798074]
#  [20.64318336]
#  [24.11235006]
#  [23.78136738]
#  [23.22067972]
#  [22.88213167]
#  [23.13837603]
#  [23.2236321 ]
#  [24.31155322]
#  [-0.53378797]
#  [21.96662441]
#  [23.79444377]
#  [23.14625604]
#  [24.21108634]
#  [22.61929916]
#  [-0.27667279]
#  [24.01785248]
#  [23.32148248]
#  [23.91165248]
#  [23.34962033]
#  [22.71281843]
#  [23.86537985]
#  [20.65078413]
#  [ 4.98652919]
#  [23.18275699]
#  [24.03741363]
#  [23.94332135]
#  [23.78970266]
#  [23.1869262 ]
#  [23.74199952]
#  [18.44824124]
#  [22.78676802]
#  [24.11193453]
#  [-0.72053493]
#  [23.99032499]
#  [24.09315974]
#  [23.10128294]
#  [17.25496344]
#  [24.19920898]
#  [22.18241139]
#  [22.36256756]
#  [24.40452709]
#  [23.17443386]
#  [24.00284355]
#  [24.19574107]]
# Training MSE: 74.31886724749972

# %%
#saving the tarained random forest model 
save_model(model, '../models/model_'+model_type+'.joblib')
