# %%
import sys
import os

sys.path.append(os.path.abspath('../src'))
from utils import load_model, load_csv, get_accuracy_metrics

# %%
model_type = 'custom'
dataset_path = '../datasets/ready/test/'

# %%
#loeading the trained model
model = load_model('../models/model_'+model_type+'.joblib')

# %%
#loading the datasets
x_test = load_csv(dataset_path+"x_test.csv")
y_test = load_csv(dataset_path+"y_test.csv")
label_classes = y_test['species'].unique()
print(label_classes)
# Out:
# [1 0 2]

# %%
# Get predictions on the test data
y_pred_test = model.predict(x_test)

# y_test = y_test.astype(str)
# y_pred_test = y_pred_test.astype(str)


get_accuracy_metrics(y_test, y_pred_test, label_classes)
# Out:
# 1.9
# sepal_length    6.4
# sepal_width     2.9
# petal_length    4.3
# petal_width     1.3
# Name: 0, dtype: float64
# 4.7
# sepal_length    6.4
# sepal_width     2.9
# petal_length    4.3
# petal_width     1.3
# Name: 0, dtype: float64
# 4.9
# sepal_length    6.4
# sepal_width     2.9
# petal_length    4.3
# petal_width     1.3
# Name: 0, dtype: float64
# None
# sepal_length    6.4
# sepal_width     2.9
# petal_length    4.3
# petal_width     1.3
# Name: 0, dtype: float64
# 1.9
# sepal_length    4.9
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.2
# Name: 1, dtype: float64
# None
# sepal_length    4.9
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.2
# Name: 1, dtype: float64
# 1.9
# sepal_length    5.6
# sepal_width     2.7
# petal_length    4.2
# petal_width     1.3
# Name: 2, dtype: float64
# 4.7
# sepal_length    5.6
# sepal_width     2.7
# petal_length    4.2
# petal_width     1.3
# Name: 2, dtype: float64
# 4.9
# sepal_length    5.6
# sepal_width     2.7
# petal_length    4.2
# petal_width     1.3
# Name: 2, dtype: float64
# None
# sepal_length    5.6
# sepal_width     2.7
# petal_length    4.2
# petal_width     1.3
# Name: 2, dtype: float64
# 1.9
# sepal_length    5.0
# sepal_width     3.4
# petal_length    1.5
# petal_width     0.2
# Name: 3, dtype: float64
# None
# sepal_length    5.0
# sepal_width     3.4
# petal_length    1.5
# petal_width     0.2
# Name: 3, dtype: float64
# 1.9
# sepal_length    5.0
# sepal_width     2.0
# petal_length    3.5
# petal_width     1.0
# Name: 4, dtype: float64
# 4.7
# sepal_length    5.0
# sepal_width     2.0
# petal_length    3.5
# petal_width     1.0
# Name: 4, dtype: float64
# 4.9
# sepal_length    5.0
# sepal_width     2.0
# petal_length    3.5
# petal_width     1.0
# Name: 4, dtype: float64
# None
# sepal_length    5.0
# sepal_width     2.0
# petal_length    3.5
# petal_width     1.0
# Name: 4, dtype: float64
# 1.9
# sepal_length    4.8
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.1
# Name: 5, dtype: float64
# None
# sepal_length    4.8
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.1
# Name: 5, dtype: float64
# 1.9
# sepal_length    6.9
# sepal_width     3.1
# petal_length    4.9
# petal_width     1.5
# Name: 6, dtype: float64
# 4.7
# sepal_length    6.9
# sepal_width     3.1
# petal_length    4.9
# petal_width     1.5
# Name: 6, dtype: float64
# 5.1
# sepal_length    6.9
# sepal_width     3.1
# petal_length    4.9
# petal_width     1.5
# Name: 6, dtype: float64
# 1.7
# sepal_length    6.9
# sepal_width     3.1
# petal_length    4.9
# petal_width     1.5
# Name: 6, dtype: float64
# 1.5
# sepal_length    6.9
# sepal_width     3.1
# petal_length    4.9
# petal_width     1.5
# Name: 6, dtype: float64
# 4.9
# sepal_length    6.9
# sepal_width     3.1
# petal_length    4.9
# petal_width     1.5
# Name: 6, dtype: float64
# None
# sepal_length    6.9
# sepal_width     3.1
# petal_length    4.9
# petal_width     1.5
# Name: 6, dtype: float64
# 1.9
# sepal_length    4.3
# sepal_width     3.0
# petal_length    1.1
# petal_width     0.1
# Name: 7, dtype: float64
# None
# sepal_length    4.3
# sepal_width     3.0
# petal_length    1.1
# petal_width     0.1
# Name: 7, dtype: float64
# 1.9
# sepal_length    5.2
# sepal_width     2.7
# petal_length    3.9
# petal_width     1.4
# Name: 8, dtype: float64
# 4.7
# sepal_length    5.2
# sepal_width     2.7
# petal_length    3.9
# petal_width     1.4
# Name: 8, dtype: float64
# 4.9
# sepal_length    5.2
# sepal_width     2.7
# petal_length    3.9
# petal_width     1.4
# Name: 8, dtype: float64
# None
# sepal_length    5.2
# sepal_width     2.7
# petal_length    3.9
# petal_width     1.4
# Name: 8, dtype: float64
# 1.9
# sepal_length    7.2
# sepal_width     3.2
# petal_length    6.0
# petal_width     1.8
# Name: 9, dtype: float64
# 4.7
# sepal_length    7.2
# sepal_width     3.2
# petal_length    6.0
# petal_width     1.8
# Name: 9, dtype: float64
# 5.1
# sepal_length    7.2
# sepal_width     3.2
# petal_length    6.0
# petal_width     1.8
# Name: 9, dtype: float64
# None
# sepal_length    7.2
# sepal_width     3.2
# petal_length    6.0
# petal_width     1.8
# Name: 9, dtype: float64
# 1.9
# sepal_length    5.4
# sepal_width     3.9
# petal_length    1.7
# petal_width     0.4
# Name: 10, dtype: float64
# None
# sepal_length    5.4
# sepal_width     3.9
# petal_length    1.7
# petal_width     0.4
# Name: 10, dtype: float64
# 1.9
# sepal_length    5.8
# sepal_width     4.0
# petal_length    1.2
# petal_width     0.2
# Name: 11, dtype: float64
# None
# sepal_length    5.8
# sepal_width     4.0
# petal_length    1.2
# petal_width     0.2
# Name: 11, dtype: float64
# 1.9
# sepal_length    6.3
# sepal_width     3.3
# petal_length    6.0
# petal_width     2.5
# Name: 12, dtype: float64
# 4.7
# sepal_length    6.3
# sepal_width     3.3
# petal_length    6.0
# petal_width     2.5
# Name: 12, dtype: float64
# 5.1
# sepal_length    6.3
# sepal_width     3.3
# petal_length    6.0
# petal_width     2.5
# Name: 12, dtype: float64
# None
# sepal_length    6.3
# sepal_width     3.3
# petal_length    6.0
# petal_width     2.5
# Name: 12, dtype: float64
# 1.9
# sepal_length    6.0
# sepal_width     2.9
# petal_length    4.5
# petal_width     1.5
# Name: 13, dtype: float64
# 4.7
# sepal_length    6.0
# sepal_width     2.9
# petal_length    4.5
# petal_width     1.5
# Name: 13, dtype: float64
# 4.9
# sepal_length    6.0
# sepal_width     2.9
# petal_length    4.5
# petal_width     1.5
# Name: 13, dtype: float64
# None
# sepal_length    6.0
# sepal_width     2.9
# petal_length    4.5
# petal_width     1.5
# Name: 13, dtype: float64
# 1.9
# sepal_length    4.4
# sepal_width     3.0
# petal_length    1.3
# petal_width     0.2
# Name: 14, dtype: float64
# None
# sepal_length    4.4
# sepal_width     3.0
# petal_length    1.3
# petal_width     0.2
# Name: 14, dtype: float64
# 1.9
# sepal_length    4.5
# sepal_width     2.3
# petal_length    1.3
# petal_width     0.3
# Name: 15, dtype: float64
# None
# sepal_length    4.5
# sepal_width     2.3
# petal_length    1.3
# petal_width     0.3
# Name: 15, dtype: float64
# 1.9
# sepal_length    6.2
# sepal_width     2.2
# petal_length    4.5
# petal_width     1.5
# Name: 16, dtype: float64
# 4.7
# sepal_length    6.2
# sepal_width     2.2
# petal_length    4.5
# petal_width     1.5
# Name: 16, dtype: float64
# 4.9
# sepal_length    6.2
# sepal_width     2.2
# petal_length    4.5
# petal_width     1.5
# Name: 16, dtype: float64
# None
# sepal_length    6.2
# sepal_width     2.2
# petal_length    4.5
# petal_width     1.5
# Name: 16, dtype: float64
# 1.9
# sepal_length    4.8
# sepal_width     3.4
# petal_length    1.6
# petal_width     0.2
# Name: 17, dtype: float64
# None
# sepal_length    4.8
# sepal_width     3.4
# petal_length    1.6
# petal_width     0.2
# Name: 17, dtype: float64
# 1.9
# sepal_length    6.8
# sepal_width     2.8
# petal_length    4.8
# petal_width     1.4
# Name: 18, dtype: float64
# 4.7
# sepal_length    6.8
# sepal_width     2.8
# petal_length    4.8
# petal_width     1.4
# Name: 18, dtype: float64
# 5.1
# sepal_length    6.8
# sepal_width     2.8
# petal_length    4.8
# petal_width     1.4
# Name: 18, dtype: float64
# 1.7
# sepal_length    6.8
# sepal_width     2.8
# petal_length    4.8
# petal_width     1.4
# Name: 18, dtype: float64
# 1.5
# sepal_length    6.8
# sepal_width     2.8
# petal_length    4.8
# petal_width     1.4
# Name: 18, dtype: float64
# 4.9
# sepal_length    6.8
# sepal_width     2.8
# petal_length    4.8
# petal_width     1.4
# Name: 18, dtype: float64
# None
# sepal_length    6.8
# sepal_width     2.8
# petal_length    4.8
# petal_width     1.4
# Name: 18, dtype: float64
# 1.9
# sepal_length    5.0
# sepal_width     2.3
# petal_length    3.3
# petal_width     1.0
# Name: 19, dtype: float64
# 4.7
# sepal_length    5.0
# sepal_width     2.3
# petal_length    3.3
# petal_width     1.0
# Name: 19, dtype: float64
# 4.9
# sepal_length    5.0
# sepal_width     2.3
# petal_length    3.3
# petal_width     1.0
# Name: 19, dtype: float64
# None
# sepal_length    5.0
# sepal_width     2.3
# petal_length    3.3
# petal_width     1.0
# Name: 19, dtype: float64
# 1.9
# sepal_length    7.7
# sepal_width     2.6
# petal_length    6.9
# petal_width     2.3
# Name: 20, dtype: float64
# 4.7
# sepal_length    7.7
# sepal_width     2.6
# petal_length    6.9
# petal_width     2.3
# Name: 20, dtype: float64
# 5.1
# sepal_length    7.7
# sepal_width     2.6
# petal_length    6.9
# petal_width     2.3
# Name: 20, dtype: float64
# None
# sepal_length    7.7
# sepal_width     2.6
# petal_length    6.9
# petal_width     2.3
# Name: 20, dtype: float64
# 1.9
# sepal_length    5.7
# sepal_width     2.8
# petal_length    4.5
# petal_width     1.3
# Name: 21, dtype: float64
# 4.7
# sepal_length    5.7
# sepal_width     2.8
# petal_length    4.5
# petal_width     1.3
# Name: 21, dtype: float64
# 4.9
# sepal_length    5.7
# sepal_width     2.8
# petal_length    4.5
# petal_width     1.3
# Name: 21, dtype: float64
# None
# sepal_length    5.7
# sepal_width     2.8
# petal_length    4.5
# petal_width     1.3
# Name: 21, dtype: float64
# 1.9
# sepal_length    5.0
# sepal_width     3.2
# petal_length    1.2
# petal_width     0.2
# Name: 22, dtype: float64
# None
# sepal_length    5.0
# sepal_width     3.2
# petal_length    1.2
# petal_width     0.2
# Name: 22, dtype: float64
# 1.9
# sepal_length    5.6
# sepal_width     2.9
# petal_length    3.6
# petal_width     1.3
# Name: 23, dtype: float64
# 4.7
# sepal_length    5.6
# sepal_width     2.9
# petal_length    3.6
# petal_width     1.3
# Name: 23, dtype: float64
# 4.9
# sepal_length    5.6
# sepal_width     2.9
# petal_length    3.6
# petal_width     1.3
# Name: 23, dtype: float64
# None
# sepal_length    5.6
# sepal_width     2.9
# petal_length    3.6
# petal_width     1.3
# Name: 23, dtype: float64
# 1.9
# sepal_length    4.9
# sepal_width     2.4
# petal_length    3.3
# petal_width     1.0
# Name: 24, dtype: float64
# 4.7
# sepal_length    4.9
# sepal_width     2.4
# petal_length    3.3
# petal_width     1.0
# Name: 24, dtype: float64
# 4.9
# sepal_length    4.9
# sepal_width     2.4
# petal_length    3.3
# petal_width     1.0
# Name: 24, dtype: float64
# None
# sepal_length    4.9
# sepal_width     2.4
# petal_length    3.3
# petal_width     1.0
# Name: 24, dtype: float64
# 1.9
# sepal_length    4.6
# sepal_width     3.6
# petal_length    1.0
# petal_width     0.2
# Name: 25, dtype: float64
# None
# sepal_length    4.6
# sepal_width     3.6
# petal_length    1.0
# petal_width     0.2
# Name: 25, dtype: float64
# 1.9
# sepal_length    5.1
# sepal_width     3.7
# petal_length    1.5
# petal_width     0.4
# Name: 26, dtype: float64
# None
# sepal_length    5.1
# sepal_width     3.7
# petal_length    1.5
# petal_width     0.4
# Name: 26, dtype: float64
# 1.9
# sepal_length    6.4
# sepal_width     2.8
# petal_length    5.6
# petal_width     2.2
# Name: 27, dtype: float64
# 4.7
# sepal_length    6.4
# sepal_width     2.8
# petal_length    5.6
# petal_width     2.2
# Name: 27, dtype: float64
# 5.1
# sepal_length    6.4
# sepal_width     2.8
# petal_length    5.6
# petal_width     2.2
# Name: 27, dtype: float64
# None
# sepal_length    6.4
# sepal_width     2.8
# petal_length    5.6
# petal_width     2.2
# Name: 27, dtype: float64
# 1.9
# sepal_length    5.6
# sepal_width     2.8
# petal_length    4.9
# petal_width     2.0
# Name: 28, dtype: float64
# 4.7
# sepal_length    5.6
# sepal_width     2.8
# petal_length    4.9
# petal_width     2.0
# Name: 28, dtype: float64
# 5.1
# sepal_length    5.6
# sepal_width     2.8
# petal_length    4.9
# petal_width     2.0
# Name: 28, dtype: float64
# 1.7
# sepal_length    5.6
# sepal_width     2.8
# petal_length    4.9
# petal_width     2.0
# Name: 28, dtype: float64
# 3.1
# sepal_length    5.6
# sepal_width     2.8
# petal_length    4.9
# petal_width     2.0
# Name: 28, dtype: float64
# None
# sepal_length    5.6
# sepal_width     2.8
# petal_length    4.9
# petal_width     2.0
# Name: 28, dtype: float64
# Accuracy: 0.97
# Precision: 0.97
# Recall: 0.97
# F1 Score: 0.97
# /mnt/c/Users/sadeg/source/repos/ML-Algorithms-From-Scratch/Decision-Tree/src/decision_tree.py:117: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif x[node.feature] <= node.threshold:

# %%
print(y_test.shape)
# Out:
# (29, 1)

# %%
print(y_pred_test.shape)
# Out:
# (29,)
