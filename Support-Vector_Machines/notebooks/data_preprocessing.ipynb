# %%
import sys
import os
# %matplotlib inline
# Add the src directory to the Python path
sys.path.append(os.path.abspath('../src'))
from data_prepocessing import split_data, normalize_data
from utils import save_dataframe_as_csv, load_data, set_pandas_options

# %%
#loading the dataset
path = '../datasets/raw/brest_cancer_dataset.csv'
df = load_data(path)
df.shape
# Out:
# (569, 33)

# %%
set_pandas_options()

# %%
# Removing duplicate and null values
df = df.drop(columns=['Unnamed: 32'])
df = df.dropna()
df.drop_duplicates(keep=False) 
df.shape
# Out:
# (569, 32)

# %%
print(df.shape)
#selecting the feature columns 
feature_columns = ["radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean","radius_se","texture_se","perimeter_se","area_se","smoothness_se","compactness_se","concavity_se","concave points_se","symmetry_se","fractal_dimension_se","radius_worst","texture_worst","perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst","concave points_worst","symmetry_worst","fractal_dimension_worst"]

#selecting the label column
label_columns = "diagnosis"

#shuffleing the data before splitting
df = df.sample(frac=1).reset_index(drop=True)

#spiliting the data into x_train, y_train, x_test, y_test
x_train, x_test, y_train, y_test = split_data(df, feature_columns, label_columns)
# Out:
# (569, 32)

# %%
normalization_method = 'min_max'
normalize_data(df, normalization_method, feature_columns)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_worst
# 0       842302         M     0.521037      0.022658        0.545989   0.363733         0.593753          0.792037        0.703140             0.731113  ...      0.620776       0.141525         0.668310    0.450698          0.601136           0.619292         0.568610              0.912027        0.598462                 0.418864
# 1      8912284         B     0.279663      0.202570        0.278419   0.158261         0.230658          0.234403        0.261246             0.168489  ...      0.212380       0.204424         0.207729    0.100865          0.185498           0.198320         0.267093              0.349485        0.085551                 0.106454
# 2     90401602         B     0.275403      0.262090        0.271301   0.154740         0.251061          0.213392        0.173149             0.202932  ...      0.206688       0.240938         0.200757    0.099735          0.159612           0.149324         0.151837              0.285086        0.083383                 0.101600
# 3    871001502         B     0.058592      0.371660        0.065510   0.025620         0.373928          0.340838        0.309513             0.107753  ...      0.041338       0.471748         0.038199    0.015877          0.606419           0.391681         0.429792              0.270756        0.346343                 0.613669
# 4       925311         B     0.199678      0.664863        0.185751   0.102863         0.197346          0.049690        0.000000             0.000000  ...      0.141942       0.700426         0.123413    0.062525          0.141980           0.026826         0.000000              0.000000        0.000197                 0.026302
# ..         ...       ...          ...           ...             ...        ...              ...               ...             ...                  ...  ...           ...            ...              ...         ...               ...                ...              ...                   ...             ...                      ...
# 564     925277         B     0.360121      0.438620        0.363486   0.217858         0.289790          0.348506        0.241097             0.185686  ...      0.268588       0.406450         0.276358    0.134757          0.207555           0.281175         0.292492              0.379725        0.136606                 0.163977
# 565     916799         M     0.536182      0.367602        0.532168   0.385366         0.489031          0.323354        0.367619             0.469732  ...      0.495553       0.377932         0.457144    0.321422          0.515288           0.219567         0.300240              0.518900        0.297457                 0.154729
# 566   88119002         M     0.593923      0.769699        0.581922   0.457900         0.285005          0.287160        0.268276             0.329871  ...      0.710423       0.889925         0.646397    0.563262          0.459816           0.371016         0.319089              0.558419        0.226296                 0.135380
# 567     906024         B     0.270671      0.083192        0.256306   0.149099         0.317956          0.118275        0.055295             0.119384  ...      0.203486       0.130597         0.187808    0.093811          0.397742           0.129435         0.074960              0.282612        0.238518                 0.259740
# 568     904689         B     0.282976      0.290159        0.279110   0.161909         0.188499          0.182842        0.095056             0.093588  ...      0.220562       0.335554         0.228597    0.107329          0.146074           0.198417         0.128115              0.227079        0.323674                 0.114325
#
# [569 rows x 32 columns]

# %%
#saving the x_train, y_train, x_test, y_test
save_dataframe_as_csv(x_train, "../datasets/ready/train/x_train.csv")
save_dataframe_as_csv(y_train, "../datasets/ready/train/y_train.csv")
save_dataframe_as_csv(x_test, "../datasets/ready/test/x_test.csv")
save_dataframe_as_csv(y_test, "../datasets/ready/test/y_test.csv")
