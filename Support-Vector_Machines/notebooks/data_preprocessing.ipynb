# %%
import sys
import os
# %matplotlib inline
# Add the src directory to the Python path
sys.path.append(os.path.abspath('../src'))
from data_prepocessing import split_data, normalize_data
from utils import save_dataframe_as_csv, load_data, set_pandas_options

# %%
#loading the dataset
path = '../datasets/raw/brest_cancer_dataset.csv'
df = load_data(path)
df.shape
# Out:
# (569, 33)

# %%
set_pandas_options()

# %%
# Removing duplicate and null values
df = df.drop(columns=['Unnamed: 32'])
df = df.dropna()
df.drop_duplicates(keep=False) 
df.shape
# Out:
# (569, 32)

# %%
print(df.shape)
#selecting the feature columns 
# feature_columns = ["radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean","radius_se","texture_se","perimeter_se","area_se","smoothness_se","compactness_se","concavity_se","concave points_se","symmetry_se","fractal_dimension_se","radius_worst","texture_worst","perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst","concave points_worst","symmetry_worst","fractal_dimension_worst"]
feature_columns = ["radius_mean","texture_mean","perimeter_mean"]

#selecting the label column
label_columns = "diagnosis"

#shuffleing the data before splitting
df = df.sample(frac=1).reset_index(drop=True)

#spiliting the data into x_train, y_train, x_test, y_test
x_train, x_test, y_train, y_test = split_data(df, feature_columns, label_columns)
# Out:
# (569, 32)

# %%
normalization_method = 'min_max'
normalize_data(df, normalization_method, feature_columns)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_worst
# 0     8910499         B     0.312793      0.410213        0.299703      561.0          0.07956           0.08259         0.04072             0.021420  ...         14.80          30.04            97.66       661.5            0.1005             0.1730          0.14530               0.06189          0.2446                  0.07024
# 1      909410         B     0.333144      0.201217        0.316495      606.5          0.07966           0.05581         0.02087             0.026520  ...         14.91          19.31            96.53       688.9            0.1034             0.1017          0.06260               0.08216          0.2136                  0.06710
# 2    88119002         M     0.593923      0.769699        0.581922     1223.0          0.08420           0.11300         0.11450             0.066370  ...         27.90          45.41           180.20      2477.0            0.1408             0.4097          0.39950               0.16250          0.2713                  0.07568
# 3     8712766         M     0.496427      0.506256        0.499689      984.6          0.10490           0.16030         0.21590             0.104300  ...         23.14          32.33           155.30      1660.0            0.1376             0.3830          0.48900               0.17210          0.2160                  0.09300
# 4      862548         M     0.352075      0.340210        0.350287      642.5          0.09752           0.11410         0.09388             0.058390  ...         16.33          30.86           109.50       826.4            0.1431             0.3026          0.31940               0.15650          0.2718                  0.09353
# ..        ...       ...          ...           ...             ...        ...              ...               ...             ...                  ...  ...           ...            ...              ...         ...               ...                ...              ...                   ...             ...                      ...
# 564    926125         M     0.659709      0.520122        0.685578     1347.0          0.10990           0.22360         0.31740             0.147400  ...         24.29          29.41           179.10      1819.0            0.1407             0.4186          0.65990               0.25420          0.2929                  0.09873
# 565    869254         B     0.178380      0.177883        0.169097      355.3          0.07793           0.05139         0.02251             0.007875  ...         11.95          20.72            77.79       441.2            0.1076             0.1223          0.09755               0.03413          0.2300                  0.06769
# 566     86561         B     0.325098      0.253635        0.308548      588.7          0.08785           0.06136         0.01420             0.011410  ...         15.49          23.58           100.30       725.9            0.1157             0.1350          0.08115               0.05104          0.2364                  0.07182
# 567    867387         B     0.413129      0.142712        0.402253      761.7          0.09462           0.09462         0.07135             0.059330  ...         17.50          19.25           114.30       922.8            0.1223             0.1949          0.17090               0.13740          0.2723                  0.07071
# 568    922296         B     0.294808      0.620561        0.283947      538.4          0.08671           0.06877         0.02987             0.032750  ...         14.37          37.17            92.48       629.6            0.1072             0.1381          0.10620               0.07958          0.2473                  0.06443
#
# [569 rows x 32 columns]

# %%
#saving the x_train, y_train, x_test, y_test
save_dataframe_as_csv(x_train, "../datasets/ready/train/x_train.csv")
save_dataframe_as_csv(y_train, "../datasets/ready/train/y_train.csv")
save_dataframe_as_csv(x_test, "../datasets/ready/test/x_test.csv")
save_dataframe_as_csv(y_test, "../datasets/ready/test/y_test.csv")
